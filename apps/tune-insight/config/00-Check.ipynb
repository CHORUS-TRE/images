# %% [markdown]
# # Welcome to Tune Insight JupyterLab
#
# This notebook provides an quick check to ensure the Tune Insight SDK was installed correctly.

# %% [markdown]
# ### Installation
#
# The Tune Insight SDK was already installed in the current container.

# %% [markdown]
# ### Check the install
#
# Run the following cell. The expected output is
#
# ```
# # Package is available          ✅
# # Cryptolib is available        ✅
# The Tune Insight SDK is correctly installed.
# ```

# %%
# %%sh
# test-ti-install

# %% [markdown]
# ## Next steps
#
# Please open the ```01-Quickstart``` notebook and follow the instructions.
